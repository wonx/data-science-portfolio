# %% [markdown]
# ### Rúbrica

# %% [markdown]
# Estructures de dades i funcions (20%):
#
# 1. Sense estructures de dades
# 2. Només llistes.
# 3. Llistes, tuples i diccionaris.
# 4. Llistes, tuples, diccionaris, llistes de comprensió i funcions lambda. ***--> Estem aquí***
#
# POO (20%):
# 1. No s'utilitza POO (o és incorrecte).
# 2. S'utilitzen classes Principal (main?), `Recomanació`, `Distancia`, `DistanciaEuclidiana` i `DistanciaPearson`, amb herència, sense redefinir `__str__` i `__equal__`.
# 3. Anterior, però `__str__` i `__equal__`.
# 4. Anterior, però `Distancia` és una classe abstracta. ***--> Estem aquí*** *(però el punt anterior (3.) no està fet, ja que sembla totalment innecessari pel funcionament del programa)*
#
# Lectura i escriptura fitxers (10%):
# 1. No es fan servir fitxers.
# 2. Es llegeixen fitxers per a llegir puntuacions.
# 3. Anterior + desar recomanacions.
# 4. Anterior, però des de classe `GestorFitxers`.  ***--> Estem aquí***
#
# Pandas i NumPy (30%):
# 1. No es fa servir Pandas.
# 2. Es fan servir només DataFrames, però només la distància euclidiana.
# 3. Es fan servir, sèries i DataFrames, i es calcula correctament la distància euclidiana, la de Pearson i es fan recomanacions adients.
# 4. Anterior + NumPy per a calcular distàncies. ***--> Estem aquí***
#
# Matplotlib (20%):
# 1. Ús incorrecte o inexistent de MatplotLib.
# 2. Només dos tipus de gràfics per a mostrar puntuacions i correlacions entre les mateixes.
# 3. Més de dos tipus de gràfics per a mostrar puntuacions i correlacions entre les mateixes, i es personalitzen.
# 4. Anterior + integrat a GoogleColab o JupyterLab.  ***--> Estem aquí***
